# %%
import numpy as n

list = n.array([[1, 2, 4,],
                [1, 2, 4]])
list
# Out:
# <>:3: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:3: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# /tmp/ipykernel_29288/1708213544.py:3: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   list = n.array[[1, 2, 4,]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import numpy as n
# ----> 3 list = n.array[[1, 2, 4,]
#       4                 [1, 2, 4]]
#       5 list
#
# TypeError: list indices must be integers or slices, not tuple
