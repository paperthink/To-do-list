# %%
work = []

# %%
while True:
    
    w = input("Enter ur work to do for today!: ")
    if w == None:
        print("Thank you for using paperthink list!")
        break
    work.append(w)
# Out:
# Thank you for using paperthink list!
